# %%
import pandas as pd

# %%
Mushroom_df=pd.read_csv("Resources/mushrooms.csv",encoding='ISO-8859-1')

# %%
Mushroom_df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
Mushroom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
#  13  stalk-surface-below-ring  8124 non-null   object
#  14  stalk-color-above-ring    8124 non-null   object
#  15  stalk-color-below-ring    8124 non-null   object
#  16  veil-type                 8124 non-null   object
#  17  veil-color                8124 non-null   object
#  18  ring-number               8124 non-null   object
#  19  ring-type                 8124 non-null   object
#  20  spore-print-color         8124 non-null   object
#  21  population                8124 non-null   object
#  22  habitat                   8124 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %%
Mushroom_df.isnull().sum().sum()
# Out:
# 0

# %%
Mushroom_df.isnull().values.any()
# Out:
# False

# %%
Mushroom_df.columns = map(str.upper,Mushroom_df.columns)

# %%
Mushroom_df
# Out:
#      CLASS CAP-SHAPE CAP-SURFACE CAP-COLOR BRUISES ODOR GILL-ATTACHMENT  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      GILL-SPACING GILL-SIZE GILL-COLOR  ... STALK-SURFACE-BELOW-RING  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      STALK-COLOR-ABOVE-RING STALK-COLOR-BELOW-RING VEIL-TYPE VEIL-COLOR  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      RING-NUMBER RING-TYPE SPORE-PRINT-COLOR POPULATION HABITAT
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
Mushroom_df = Mushroom_df.rename(columns={'CLASS' : 'EDIBLE OR POISONOUS'})

# %%
Mushroom_df
# Out:
#      EDIBLE OR POISONOUS CAP-SHAPE CAP-SURFACE CAP-COLOR BRUISES ODOR  \
# 0                      p         x           s         n       t    p
# 1                      e         x           s         y       t    a
# 2                      e         b           s         w       t    l
# 3                      p         x           y         w       t    p
# 4                      e         x           s         g       f    n
# ...                  ...       ...         ...       ...     ...  ...
# 8119                   e         k           s         n       f    n
# 8120                   e         x           s         n       f    n
# 8121                   e         f           s         n       f    n
# 8122                   p         k           y         n       f    y
# 8123                   e         x           s         n       f    n
#
#      GILL-ATTACHMENT GILL-SPACING GILL-SIZE GILL-COLOR  ...  \
# 0                  f            c         n          k  ...
# 1                  f            c         b          k  ...
# 2                  f            c         b          n  ...
# 3                  f            c         n          n  ...
# 4                  f            w         b          k  ...
# ...              ...          ...       ...        ...  ...
# 8119               a            c         b          y  ...
# 8120               a            c         b          y  ...
# 8121               a            c         b          n  ...
# 8122               f            c         n          b  ...
# 8123               a            c         b          y  ...
#
#      STALK-SURFACE-BELOW-RING STALK-COLOR-ABOVE-RING STALK-COLOR-BELOW-RING  \
# 0                           s                      w                      w
# 1                           s                      w                      w
# 2                           s                      w                      w
# 3                           s                      w                      w
# 4                           s                      w                      w
# ...                       ...                    ...                    ...
# 8119                        s                      o                      o
# 8120                        s                      o                      o
# 8121                        s                      o                      o
# 8122                        k                      w                      w
# 8123                        s                      o                      o
#
#      VEIL-TYPE VEIL-COLOR RING-NUMBER RING-TYPE SPORE-PRINT-COLOR POPULATION  \
# 0            p          w           o         p                 k          s
# 1            p          w           o         p                 n          n
# 2            p          w           o         p                 n          n
# 3            p          w           o         p                 k          s
# 4            p          w           o         e                 n          a
# ...        ...        ...         ...       ...               ...        ...
# 8119         p          o           o         p                 b          c
# 8120         p          n           o         p                 b          v
# 8121         p          o           o         p                 b          c
# 8122         p          w           o         e                 w          v
# 8123         p          o           o         p                 o          c
#
#      HABITAT
# 0          u
# 1          g
# 2          m
# 3          u
# 4          g
# ...      ...
# 8119       l
# 8120       l
# 8121       l
# 8122       l
# 8123       l
#
# [8124 rows x 23 columns]

# %%
Final_Mushroom_df=Mushroom_df.drop(columns=['STALK-SHAPE', 'STALK-SURFACE-ABOVE-RING','STALK-SURFACE-BELOW-RING','STALK-COLOR-ABOVE-RING','STALK-COLOR-BELOW-RING','VEIL-TYPE','VEIL-COLOR','RING-NUMBER','RING-TYPE'])

# %%
Final_Mushroom_df['EDIBLE OR POISONOUS'] = Final_Mushroom_df['EDIBLE OR POISONOUS'].map({'p':'Poisonous','e':'Edible'})
Final_Mushroom_df['CAP-SHAPE']=Final_Mushroom_df['CAP-SHAPE'].map({'b':'Bell','c':'Conical','x':'Convex','f':'Flat','k':'Knobbed','s':'Sunken'})
Final_Mushroom_df['CAP-SURFACE']=Final_Mushroom_df['CAP-SURFACE'].map({'f':'Fibrous','g':'Grooves','y':'Scaly','s':'Smooth'})
Final_Mushroom_df['BRUISES']=Final_Mushroom_df['BRUISES'].map({'t':'Bruises','f':'No'})
Final_Mushroom_df['ODOR']=Final_Mushroom_df['ODOR'].map({'a':'Almond','l':'Anise','c':'Creosote','y':'Fishy','f':'Foul','m':'Musty','n':'None','p':'Pungent','s':'spicy'})
Final_Mushroom_df['GILL-ATTACHMENT'] = Final_Mushroom_df['GILL-ATTACHMENT'].map({'a':'Attached','d':'Descending','f':'Free','n':'Notched'})
Final_Mushroom_df['CAP-COLOR']=Final_Mushroom_df['CAP-COLOR'].map({'n':'Brown','b':'Buff','c':'Cinnamon','g':'Gray','r':'Green','p':'Pink','u':'Purple','e':'Red','w':'White','y':'Yellow'})
Final_Mushroom_df['GILL-ATTACHMENT']=Final_Mushroom_df['GILL-ATTACHMENT'].map({'a':'Attached','d':'Descending','f':'Free','n':'Notched'})
Final_Mushroom_df['GILL-SPACING']=Final_Mushroom_df['GILL-SPACING'].map({'c':'Close','w':'Crowded','d':'Distant'})
Final_Mushroom_df['GILL-SIZE']=Final_Mushroom_df['GILL-SIZE'].map({'b':'Broad','n':'Narrow'})
Final_Mushroom_df['GILL-COLOR']=Final_Mushroom_df['GILL-COLOR'].map({'k':'Black','n':'Brown','b':'Buff','h':'Chocolate','g':'Gray','r':'Green','o':'Orange','p':'Pink','u':'Purple','e':'Red','w':'White','y':'Yellow'})
Final_Mushroom_df['STALK-ROOT']=Final_Mushroom_df['STALK-ROOT'].map({'b':'Bulbous','c':'Club','u':'Cup','e':'Equal','z':'Rhizomorphs','z':'Rooted'})
Final_Mushroom_df['SPORE-PRINT-COLOR']=Final_Mushroom_df['SPORE-PRINT-COLOR'].map({'k':'Black','n':'Brown','b':'Buff','h':'Chocolate','r':'Green','o':'Orange','u':'Purple','w':'White','y':'Yellow'})
Final_Mushroom_df['POPULATION']=Final_Mushroom_df['POPULATION'].map({'a':'Abundant','c':'Clustered','n':'Numerous','s':'Scattered','v':'Several','y':'Solitary'})
Final_Mushroom_df['HABITAT']=Final_Mushroom_df['HABITAT'].map({'g':'Grasses','l':'Leaves','m':'Meadows','p':'Paths','u':'Urban','w':'Waste','d':'Woods'})

# %%
Final_Mushroom_df
# Out:
#      EDIBLE OR POISONOUS CAP-SHAPE CAP-SURFACE CAP-COLOR  BRUISES     ODOR  \
# 0              Poisonous    Convex      Smooth     Brown  Bruises  Pungent
# 1                 Edible    Convex      Smooth    Yellow  Bruises   Almond
# 2                 Edible      Bell      Smooth     White  Bruises    Anise
# 3              Poisonous    Convex       Scaly     White  Bruises  Pungent
# 4                 Edible    Convex      Smooth      Gray       No     None
# ...                  ...       ...         ...       ...      ...      ...
# 8119              Edible   Knobbed      Smooth     Brown       No     None
# 8120              Edible    Convex      Smooth     Brown       No     None
# 8121              Edible      Flat      Smooth     Brown       No     None
# 8122           Poisonous   Knobbed       Scaly     Brown       No    Fishy
# 8123              Edible    Convex      Smooth     Brown       No     None
#
#      GILL-ATTACHMENT GILL-SPACING GILL-SIZE GILL-COLOR STALK-ROOT  \
# 0                NaN        Close    Narrow      Black      Equal
# 1                NaN        Close     Broad      Black       Club
# 2                NaN        Close     Broad      Brown       Club
# 3                NaN        Close    Narrow      Brown      Equal
# 4                NaN      Crowded     Broad      Black      Equal
# ...              ...          ...       ...        ...        ...
# 8119             NaN        Close     Broad     Yellow        NaN
# 8120             NaN        Close     Broad     Yellow        NaN
# 8121             NaN        Close     Broad      Brown        NaN
# 8122             NaN        Close    Narrow       Buff        NaN
# 8123             NaN        Close     Broad     Yellow        NaN
#
#      SPORE-PRINT-COLOR POPULATION  HABITAT
# 0                Black  Scattered    Urban
# 1                Brown   Numerous  Grasses
# 2                Brown   Numerous  Meadows
# 3                Black  Scattered    Urban
# 4                Brown   Abundant  Grasses
# ...                ...        ...      ...
# 8119              Buff  Clustered   Leaves
# 8120              Buff    Several   Leaves
# 8121              Buff  Clustered   Leaves
# 8122             White    Several   Leaves
# 8123            Orange  Clustered   Leaves
#
# [8124 rows x 14 columns]

# %%
Mushrooms_df=Final_Mushroom_df.drop(columns=['GILL-ATTACHMENT'])

# %%
Mushrooms_df
# Out:
#      EDIBLE OR POISONOUS CAP-SHAPE CAP-SURFACE CAP-COLOR  BRUISES     ODOR  \
# 0              Poisonous    Convex      Smooth     Brown  Bruises  Pungent
# 1                 Edible    Convex      Smooth    Yellow  Bruises   Almond
# 2                 Edible      Bell      Smooth     White  Bruises    Anise
# 3              Poisonous    Convex       Scaly     White  Bruises  Pungent
# 4                 Edible    Convex      Smooth      Gray       No     None
# ...                  ...       ...         ...       ...      ...      ...
# 8119              Edible   Knobbed      Smooth     Brown       No     None
# 8120              Edible    Convex      Smooth     Brown       No     None
# 8121              Edible      Flat      Smooth     Brown       No     None
# 8122           Poisonous   Knobbed       Scaly     Brown       No    Fishy
# 8123              Edible    Convex      Smooth     Brown       No     None
#
#      GILL-SPACING GILL-SIZE GILL-COLOR STALK-ROOT SPORE-PRINT-COLOR  \
# 0           Close    Narrow      Black      Equal             Black
# 1           Close     Broad      Black       Club             Brown
# 2           Close     Broad      Brown       Club             Brown
# 3           Close    Narrow      Brown      Equal             Black
# 4         Crowded     Broad      Black      Equal             Brown
# ...           ...       ...        ...        ...               ...
# 8119        Close     Broad     Yellow        NaN              Buff
# 8120        Close     Broad     Yellow        NaN              Buff
# 8121        Close     Broad      Brown        NaN              Buff
# 8122        Close    Narrow       Buff        NaN             White
# 8123        Close     Broad     Yellow        NaN            Orange
#
#      POPULATION  HABITAT
# 0     Scattered    Urban
# 1      Numerous  Grasses
# 2      Numerous  Meadows
# 3     Scattered    Urban
# 4      Abundant  Grasses
# ...         ...      ...
# 8119  Clustered   Leaves
# 8120    Several   Leaves
# 8121  Clustered   Leaves
# 8122    Several   Leaves
# 8123  Clustered   Leaves
#
# [8124 rows x 13 columns]

# %%
Mushrooms_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EDIBLE OR POISONOUS  8124 non-null   object
#  1   CAP-SHAPE            8124 non-null   object
#  2   CAP-SURFACE          8124 non-null   object
#  3   CAP-COLOR            8124 non-null   object
#  4   BRUISES              8124 non-null   object
#  5   ODOR                 8124 non-null   object
#  6   GILL-SPACING         8124 non-null   object
#  7   GILL-SIZE            8124 non-null   object
#  8   GILL-COLOR           8124 non-null   object
#  9   STALK-ROOT           5452 non-null   object
#  10  SPORE-PRINT-COLOR    8124 non-null   object
#  11  POPULATION           8124 non-null   object
#  12  HABITAT              8124 non-null   object
# dtypes: object(13)
# memory usage: 825.2+ KB

# %%
Mushrooms_df.isnull().sum()
# Out:
# EDIBLE OR POISONOUS       0
# CAP-SHAPE                 0
# CAP-SURFACE               0
# CAP-COLOR                 0
# BRUISES                   0
# ODOR                      0
# GILL-SPACING              0
# GILL-SIZE                 0
# GILL-COLOR                0
# STALK-ROOT             2672
# SPORE-PRINT-COLOR         0
# POPULATION                0
# HABITAT                   0
# dtype: int64

# %%
Mushrooms_df.dropna(inplace=True)

# %%
Mushrooms_df
# Out:
#      EDIBLE OR POISONOUS CAP-SHAPE CAP-SURFACE CAP-COLOR  BRUISES     ODOR  \
# 0              Poisonous    Convex      Smooth     Brown  Bruises  Pungent
# 1                 Edible    Convex      Smooth    Yellow  Bruises   Almond
# 2                 Edible      Bell      Smooth     White  Bruises    Anise
# 3              Poisonous    Convex       Scaly     White  Bruises  Pungent
# 4                 Edible    Convex      Smooth      Gray       No     None
# ...                  ...       ...         ...       ...      ...      ...
# 7986              Edible      Bell       Scaly     Brown       No     None
# 8001              Edible    Convex       Scaly     Brown       No     None
# 8038              Edible    Convex       Scaly      Gray  Bruises     None
# 8095           Poisonous    Convex       Scaly  Cinnamon       No    Musty
# 8114           Poisonous      Flat       Scaly  Cinnamon       No    Musty
#
#      GILL-SPACING GILL-SIZE GILL-COLOR STALK-ROOT SPORE-PRINT-COLOR  \
# 0           Close    Narrow      Black      Equal             Black
# 1           Close     Broad      Black       Club             Brown
# 2           Close     Broad      Brown       Club             Brown
# 3           Close    Narrow      Brown      Equal             Black
# 4         Crowded     Broad      Black      Equal             Brown
# ...           ...       ...        ...        ...               ...
# 7986        Close     Broad      White    Bulbous             White
# 8001        Close     Broad      White    Bulbous             White
# 8038        Close     Broad      White    Bulbous             White
# 8095        Close     Broad     Yellow       Club             White
# 8114        Close     Broad     Yellow       Club             White
#
#      POPULATION  HABITAT
# 0     Scattered    Urban
# 1      Numerous  Grasses
# 2      Numerous  Meadows
# 3     Scattered    Urban
# 4      Abundant  Grasses
# ...         ...      ...
# 7986   Solitary    Paths
# 8001   Solitary    Paths
# 8038   Solitary    Paths
# 8095  Clustered    Woods
# 8114  Clustered    Woods
#
# [5452 rows x 13 columns]

# %%
Mushrooms_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5452 entries, 0 to 8114
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EDIBLE OR POISONOUS  5452 non-null   object
#  1   CAP-SHAPE            5452 non-null   object
#  2   CAP-SURFACE          5452 non-null   object
#  3   CAP-COLOR            5452 non-null   object
#  4   BRUISES              5452 non-null   object
#  5   ODOR                 5452 non-null   object
#  6   GILL-SPACING         5452 non-null   object
#  7   GILL-SIZE            5452 non-null   object
#  8   GILL-COLOR           5452 non-null   object
#  9   STALK-ROOT           5452 non-null   object
#  10  SPORE-PRINT-COLOR    5452 non-null   object
#  11  POPULATION           5452 non-null   object
#  12  HABITAT              5452 non-null   object
# dtypes: object(13)
# memory usage: 596.3+ KB
